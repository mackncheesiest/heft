# %%
from heft import heft, gantt
import numpy as np

# %%
comp_matrix_1 = heft.readCsvToNumpyMatrix('../test/canonicalgraph_task_exe_time.csv')
comm_matrix_1 = heft.readCsvToNumpyMatrix('../test/canonicalgraph_resource_BW.csv')
dag1 = heft.readDagMatrix('../test/canonicalgraph_task_connectivity.csv')

comp_matrix_2 = heft.readCsvToNumpyMatrix('../test/randomgraph_task_exe_time.csv')
comm_matrix_2 = heft.readCsvToNumpyMatrix('../test/randomgraph_resource_BW.csv')
dag2 = heft.readDagMatrix('../test/randomgraph_task_connectivity.csv')

# %%
"""
Schedule the first graph with the standard averaging rank-u metric
"""
sched, task_sched, _ = heft.schedule_dag(dag1, 
                                communication_matrix=comm_matrix_1, 
                                computation_matrix=comp_matrix_1)
gantt.showGanttChart(sched)
print('End: ', task_sched[9].end)
# Out:
# Node: 1, RankU: 108.0
#
# Node: 4, RankU: 80.0
#
# Node: 3, RankU: 79.99999999999999
#
# Node: 2, RankU: 77.0
#
# Node: 5, RankU: 69.0
#
# Node: 6, RankU: 63.33333333333333
#
# Node: 9, RankU: 44.33333333333333
#
# Node: 7, RankU: 42.666666666666664
#
# Node: 8, RankU: 35.666666666666664
#
# Node: 10, RankU: 14.666666666666666
# End:  80.0

# %%
"""
Schedule the first graph with the worst-case rank-u metric
"""
sched, task_sched, _ = heft.schedule_dag(dag1, 
                                communication_matrix=comm_matrix_1, 
                                computation_matrix=comp_matrix_1,
                                rank_metric=heft.RankMetric.WORST)
gantt.showGanttChart(sched)
print('End: ', task_sched[9].end)
# Out:
# Node: 1, RankU: 71.66666666666666
#
# Node: 2, RankU: 55.666666666666664
#
# Node: 4, RankU: 52.666666666666664
#
# Node: 3, RankU: 50.666666666666664
#
# Node: 5, RankU: 49.666666666666664
#
# Node: 6, RankU: 46.666666666666664
#
# Node: 9, RankU: 35.666666666666664
#
# Node: 7, RankU: 30.666666666666664
#
# Node: 8, RankU: 29.666666666666664
#
# Node: 10, RankU: 14.666666666666666
# End:  80.0

# %%
"""
Schedule the first graph with the best-case rank-u metric
"""
sched, task_sched, _ = heft.schedule_dag(dag1, 
                                communication_matrix=comm_matrix_1, 
                                computation_matrix=comp_matrix_1,
                                rank_metric=heft.RankMetric.BEST)
gantt.showGanttChart(sched)
print('End: ', task_sched[9].end)
# Out:
# Node: 1, RankU: [[39.66666667]]
#
# Node: 5, RankU: [[37.66666667]]
#
# Node: 2, RankU: [[33.66666667]]
#
# Node: 3, RankU: [[33.66666667]]
#
# Node: 6, RankU: [[30.66666667]]
#
# Node: 4, RankU: [[29.66666667]]
#
# Node: 9, RankU: [[26.66666667]]
#
# Node: 7, RankU: [[22.66666667]]
#
# Node: 8, RankU: [[20.66666667]]
#
# Node: 10, RankU: 14.666666666666666
# End:  94.0

# %%
"""
Schedule the second graph with the standard averaging rank-u metric
"""
sched, task_sched, _ = heft.schedule_dag(dag1, 
                                communication_matrix=comm_matrix_2, 
                                computation_matrix=comp_matrix_2)
gantt.showGanttChart(sched)
print('End: ', task_sched[9].end)
# Out:
# Node: 1, RankU: 168.90689790839014
#
# Node: 5, RankU: 106.84181312374051
#
# Node: 6, RankU: 103.85605817926276
#
# Node: 2, RankU: 84.98144693253973
#
# Node: 3, RankU: 82.62657758847052
#
# Node: 4, RankU: 67.12920657494422
#
# Node: 9, RankU: 52.722804891675985
#
# Node: 8, RankU: 41.394464962453995
#
# Node: 7, RankU: 31.167611769848392
#
# Node: 10, RankU: 19.238224449713368
# End:  170.90810667681754

# %%
"""
Schedule the second graph with the worst-case rank-u metric
"""
sched, task_sched, _ = heft.schedule_dag(dag1, 
                                communication_matrix=comm_matrix_2, 
                                computation_matrix=comp_matrix_2,
                                rank_metric=heft.RankMetric.WORST)
gantt.showGanttChart(sched)
print('End: ', task_sched[9].end)
# Out:
# Node: 1, RankU: 208.22526462287686
#
# Node: 5, RankU: 133.83533626158243
#
# Node: 6, RankU: 120.54347196484935
#
# Node: 3, RankU: 112.40332638561341
#
# Node: 2, RankU: 111.36615642857885
#
# Node: 4, RankU: 92.85735235245593
#
# Node: 9, RankU: 68.36662655348634
#
# Node: 8, RankU: 57.297079377370345
#
# Node: 7, RankU: 41.512580986881005
#
# Node: 10, RankU: 19.238224449713368
# End:  175.65082688738374

# %%
"""
Schedule the second graph with the best-case rank-u metric
"""
sched, task_sched, _ = heft.schedule_dag(dag1, 
                                communication_matrix=comm_matrix_2, 
                                computation_matrix=comp_matrix_2,
                                rank_metric=heft.RankMetric.BEST)
gantt.showGanttChart(sched)
print('End: ', task_sched[9].end)
# Out:
# Node: 1, RankU: [[120.74564649]]
#
# Node: 6, RankU: [[102.99517048]]
#
# Node: 5, RankU: [[91.37896614]]
#
# Node: 2, RankU: [[82.5849638]]
#
# Node: 3, RankU: [[70.31415406]]
#
# Node: 4, RankU: [[53.78900325]]
#
# Node: 9, RankU: [[46.45825614]]
#
# Node: 8, RankU: [[43.53295113]]
#
# Node: 7, RankU: [[35.51908802]]
#
# Node: 10, RankU: 19.238224449713368
# End:  161.25003663325924

# %%
"""
Schedule the first graph with the EDP metric
"""
en_dict = np.array([
    [7, 10, 3],
    [9, 20, 15],
    [5, 9, 7],
    [4, 6, 10],
    [12, 11, 12],
    [17, 16, 10],
    [6, 6, 5],
    [7, 9, 9],
    [14, 5, 7],
    [12, 13, 14]
])

sched, task_sched, _ = heft.schedule_dag(dag1,
                             communication_matrix=comm_matrix_1,
                             computation_matrix=comp_matrix_1,
                             rank_metric=heft.RankMetric.EDP,
                             energy_dict=en_dict,
                             )
gantt.showGanttChart(sched)
# Out:
# Node: 1, RankU: 537.2222222222222
#
# Node: 2, RankU: 432.55555555555554
#
# Node: 5, RankU: 321.2222222222222
#
# Node: 6, RankU: 305.55555555555554
#
# Node: 4, RankU: 279.55555555555554
#
# Node: 3, RankU: 217.33333333333334
#
# Node: 9, RankU: 172.11111111111111
#
# Node: 8, RankU: 109.0
#
# Node: 7, RankU: 94.0
#
# Node: 10, RankU: 14.666666666666666
